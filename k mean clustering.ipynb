# %%
import matplotlib.pyplot as plt
import pandas as pd
a=pd.read_csv("new.csv")
print(a)
# print(a.to_string())
x=a.iloc[:,:4].values
# print(x)
#no traing test required
from sklearn.cluster import KMeans
kmeans=KMeans(init='k-means++',n_clusters=3,n_init=10,random_state=0).fit(x)
p=kmeans.predict(x)
print(p)
import matplotlib.pyplot as plt

colors=list(map(lambda x:'#3b4cc0' if x==1 else '#000000',p))
plt.scatter(x[:,0],x[:,1],c=colors,marker='*',picker=True)

plt.show()
# Out:
#      id  age
# 0   163  554
# 1   493  902
# 2   256  346
# 3   666  854
# 4   842   90
# ..  ...  ...
# 95  394  128
# 96  286  321
# 97  609  907
# 98  386   55
# 99  668  906
#
# [100 rows x 2 columns]
# [1 2 1 2 0 0 0 0 2 0 2 2 0 2 0 0 1 0 0 0 1 1 0 2 1 1 1 0 2 2 0 1 1 0 0 2 0
#  2 2 0 0 0 1 2 0 1 1 1 2 0 2 0 1 2 1 0 0 1 0 2 2 0 1 1 0 2 1 0 1 0 2 0 0 2
#  1 2 0 2 2 0 1 0 0 2 2 0 2 1 0 2 0 1 2 1 1 0 1 2 0 2]
